# %%
# Odd 

list=[0,1,2,3,4,5]
for i in list:
    if i % 2 == 1:
        print(i)
# Out:
# 1
# 3
# 5

# %%
list=[0,12,3,45,3,2,1]
add=[]
even=[]
def add_or_even(a):
    for i in a:
# Out:
#   Cell In[14], line 6
#
#     ^
# SyntaxError: incomplete input

# %%
# def odd(a):
#     for i in a:
#         if i % 2 == 1:
#             print(i)

# odd(list)

def even(a):
    try:  
        for i in a:
            if i == 0:
                print("zero is there")
            if i % 2 == 0:
                print(i)
    except Exception as e:
      print(f"this the error,{e}")

even(list)
# Out:
# zero is there
# 0
# 2
# 4

# %%
#fine the second largest num

lis=[1,2,4,5,6,7]
f_l=float("inf")
s_l=float("inf")

for i in lis:
    if i<f_l:
        s_l,f_l=f_l,i
    elif i<s_l:
        s_l=i
print(s_l)
print(f_l)
# Out:
# 2
# 1

# %%
first=float('inf')
second=float('inf')
for i in list:
    if i<first:
        second,first=first,i
    elif i<second:
        second=i
print('second min:',second)
print('first',first)
# Out:
# second min: 2
# first 1

# %%
#panlindrom

pali="madam"

s=pali[::-1]
if s==pali:
    print("this is panlidrom")
# Out:
# this is panlidrom

# %%
#Odd or even
#find the second largest second smallest
#prime
#palindrom

# %%
list=[1,2,3,4,5]

for i in list:
    if i%2==1:
     print(i)
# Out:
# 1
# 3
# 5

# %%
for i in list:
    if i%2==0:
     print(i)
# Out:
# 2
# 4

# %%
list=[1,2,3,4,5]
def odd_or_even(list):
    odd=[]
    even=[]
    for i in list:
        if i % 2==0:
            even.append(i)
        elif i%2==1:
            odd.append(i)
    return f"odd:{odd},even:{even}"
            
odd_or_even(list)
# Out:
# 'odd:[1, 3, 5],even:[2, 4]'

# %%
first=-1
second=-1
for i in list:
    if i>first:
        second,first=first,i
    elif i>second:
        second=i
print(second)
# Out:
# 4

# %%
first=float("inf")
second=float("inf")
for i in list:
    if i < first:
        second,first=first,i
    elif i< second:
        second=i
print(second)
# Out:
# 2

# %%
n=11

if n > 1:
    for i in range(2,n):
        if n%i==0:
            print("not prime")
            break
    else:
        print("prime")
else:
    print('grater than 1')
# Out:
# prime

# %%
pali="madam"

check=pali[::-1]
if pali == check:
    print(pali)
# Out:
# madam

# %%
#Odd or even
#find the second largest second smallest
#prime
#palindrom

# %%
list=[1,2,3,4,5]
def odd(a):
    for i in a:
        if i % 2 == 1:
            print(i)
odd(list)
print("````````````")
def even(a):
    for i in a :
        if i % 2 == 0:
            print(i)

even(list)
# Out:
# 1
# 3
# 5
# ````````````
# 2
# 4

# %%
def seconlargest(a):
    first=-1
    second=-1
    for i in a:
        if i > first:
            second,first=first,i
        elif i > second:
            second=i
    return second

seconlargest(list)
# Out:
# 4

# %%
def secondsmallest(a):
    first=float("inf")
    second=float("inf")
    for i in a:
        if i < first:
            second,first=first,i
        elif i < second:
            second=i
    return second

secondsmallest(list)
# Out:
# 2

# %%
def primeNum(a):
    for i in range(2,):
        if i < 1:
            return "more than one"
        break
        elif i

# %%
l=[1,2,3,4,5,6]
def even(a):
    for i in a:
        if i % 2==0:
            print(i)
even(l)

print("**************")

def odd(a):
    for i in a:
        if i % 2 ==1:
            print(i)

odd(l)
# Out:
# 2
# 4
# 6
# **************
# 1
# 3
# 5

# %%
list1=[[1,2],[3,4],[5,6]]
list2 = []

for i in list1:
    for j in i:
        list2.append(j)

list2
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
def prime(n):
    if n <= 1:
        print(n, "is not a prime number")
        return

    for i in range(2, n):
        if n % i == 0:
            print(n, "is not a prime number")
            return

    print(n, "is a prime number")


num = int(input("Enter the number: "))
prime(num)
# Out:
# 4 is not a prime number

# %%
for i in range(1,5+1):
    for j in range(1,i+1):
        print("* ",end="")
    print("\n")
# Out:
# *
#
# * *
#
# * * *
#
# * * * *
#
# * * * * *

# %%
*****
****
***
**
*

# %%
for i in range(5,0,-1):
    for j in range(i):
        print("i",end=" ")
    print("\n")
# Out:
# i i i i i
#
# i i i i
#
# i i i
#
# i i
#
# i

# %%
list=[1,2,3,4,5,6]
target = 8

for i in list:
    for j in list:
        s=i+j
        if s == target:
            print(i,j)
# Out:
# 2 6
# 3 5
# 4 4
# 5 3
# 6 2
